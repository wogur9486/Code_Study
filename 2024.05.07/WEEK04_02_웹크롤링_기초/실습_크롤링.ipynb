# %%
import requests
from bs4 import BeautifulSoup

# %%
# url = 'https://kin.naver.com/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&page=1'
url = 'https://kin.naver.com/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&page=2'

# %%
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
html = response.text
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="파이썬의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20240424182653/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20240424182653/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20240424182653/css/min/other.css" rel="stylesheet" type="text/css"/>
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# ...

# %%
title = soup.select_one('#s_content > div.section > ul > li:nth-child(1) > dl > dt > a')
print(title)
# Out:
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=4&amp;dirId=405&amp;docId=467918812&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=11&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 무역학과, 무역회사</a>

# %%
print(title.get_text())
# Out:
# 파이썬 무역학과, 무역회사

# %%
ul = soup.select_one('ul.basic1')

# %%
ul
# Out:
# <ul class="basic1">
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=4&amp;dirId=405&amp;docId=467918812&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=11&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 무역학과, 무역회사</a>
# </dt>
# <dd class="txt_inline">2024.04.12.</dd>
# <dd>... 배울 때 <b>파이썬</b> 혹시 사용하나요? 그리고 무역 관련 회사 취업하면 <b>파이썬</b> 많이 사용하나요? 프로그래밍 수출입 하는 회사라면 모를까 무역과 <b>파이썬</b>은 연관이 없습니다.</dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=405">무역</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# ...

# %%
titles = ul.select('li > dl > dt > a')

# %%
for title in titles:
    print(title.get_text())
# Out:
# 파이썬 질문이요
# 파이썬 초보자
# 파이썬 관련 문의
# 파이썬 불러오기
# 파이썬 서버에서 실행?
# 파이썬만 사용해서 풀기
# 파이썬 질문합니다
# 파이썬 c언어 비교 서적
# 단기간 파이썬 게임 만들기
# 파이썬을 활용하는 빅데이터 분석

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&page={}'

for page in range(1, 6):  # 페이지 1부터 5까지 순회
    url = base_url.format(page)
    response = requests.get(url)
    
    if response.status_code == 200:
        html = response.text
        soup = BeautifulSoup(html, 'html.parser')
        ul = soup.select_one('ul.basic1')
        titles = ul.select('li > dl > dt > a')
        for title in titles:
            print(title.get_text())
    else:
        print("Failed to fetch page", page)
# Out:
# 파이썬이 미래에 도움이 될까요?
# 중1 파이썬 독학
# 파이썬 사용
# 파이썬 문법 질문
# 파이썬 파이게임 init()에러
# 파이썬 질문
# 파이썬과 자바
# 파이썬 해커 되는법 파이썬 해킹에 관해서
# 파이썬 고등학교 시험
# 파이썬 기초 공부하는법 질문드려요
# 파이썬 무역학과, 무역회사
# 파이썬 질문...
# 파이썬 배우기
# 맥북 파이썬 idel
# 파이썬학원 소개좀요
# 신촌파이썬학원 괜찮은 곳 있나요!?
# 파이썬 map
# 파이썬 id함수 질문이요
# 파이썬강의 듣는데가 있나요?
# 파이썬 라이선스 분석
# 정보 수집하여 엑셀에 정리해주는 파이썬
# 파이썬 입문... 그런데 수포자입니다
# 파이썬 기말 평균 구하기
# 파이썬 실행 안됨
# 파이썬에서 엑셀 핸들링
# 파이썬강좌 독학할때 뭐보나요??
# 파이썬 질문
# 파이썬에서 증가값이 머에요?
# 파이썬 리스트 if
# 파이썬 문제 질문
# 파이썬 다이아몬드
# 파이썬 문제 풀어주세요
# 맥북 파이썬 설치
# 파이썬 코드 차이
# 고1 정보 파이썬 문제좀 풀어주세요
# 웹개발공부와 파이썬공부
# 파이썬강의 보려해요
# 파이썬 코딩 문제
# 파이썬독학할 때 어떻게 공부를...
# 파이썬 코드끼리 연결
# 파이썬 질문이요
# 파이썬 초보자
# 파이썬 관련 문의
# 파이썬 불러오기
# 파이썬 서버에서 실행?
# 파이썬만 사용해서 풀기
# 파이썬 질문합니다
# 파이썬 c언어 비교 서적
# 단기간 파이썬 게임 만들기
# 파이썬을 활용하는 빅데이터 분석
